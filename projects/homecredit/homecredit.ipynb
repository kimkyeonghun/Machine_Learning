# %%
import pandas as pd

# %%
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")
loan = pd.read_csv("./data/loan_before.csv")

# %%
train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS',
#        'HOUR_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'EXT_SOURCE_1',
#        'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_LAST_PHONE_CHANGE',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object')

# %% [markdown]
# 1. SK_ID_CURR: 아이디
# 2. TARGET: 갚았는지 여부
# 3. AMT_INCOMR_TOTAL: 수입
# 4. AMT_CREDIT: 대출금앱
# 5. AMT_ANNUITY: 1달마다 갚아야 하는 금액
# 6. NAME_TYPE_SUITE: 동행자
# 7. NAME_INCOME_TYPE: 직업 종류
# 8. REGION_POPULATION_RELATIVE: 지역의 인구
# 9. DAYS_ID_PUBLISH: ID 문서를 변경한 날짜
# 10. HOUR_APPR_PROCESS_START: 대출신청시간
# 11. EXT_SOURCE_1,2,3: 신용점수1,2,3
# 12. AMT_REQ_CREDIT_BUREAU_YEAR: 신용평가기관에 해당 사람에 대한 신용정보를 조회한 개수

# %%
loan.columns
# Out:
# Index(['SK_ID_CURR', 'DAYS_CREDIT', 'CNT_CREDIT_PROLONG', 'AMT_CREDIT_SUM',
#        'CREDIT_TYPE'],
#       dtype='object')

# %% [markdown]
# ### 문제인식
#
# 1. 어떤 요소가 대출금 상환 여부에 큰 영향을 주는가?
# 2. 그리고 그 요소들은 대출금 상환 여부에 어떤 영향을 미칠까?

# %% [markdown]
# ### 방법론
#
# #### 분석과정
#
# 이 질문에 대한 해답을 얻기 위해 해석가능한 머신러닝을 활용

# %% [markdown]
# **프로세스**
#
# Step 1: feature enginnering 수행<br>
# Step 2: 머신러닝 모델 훈련<br>
# Step 3: shap value를 통해 어떤 변수가 가장 큰 영향을 주는지 알아본다.<br>
# Step 4: 영향을 많이 주는 5개의 변수와 대출금 상환 여부와의 관계를 살펴본다.<br>

# %% [markdown]
# ## Feature Engineering

# %%
train.head()
# Out:
#    SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      162716       0          0.0             0                1
# 1      361317       0          0.0             0                1
# 2      246925       0          1.0             0                0
# 3      294331       0          1.0             1                0
# 4      152173       0          0.0             0                1
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY NAME_TYPE_SUITE  \
# 0             0          101250.0    480060.0      22509.0   Unaccompanied
# 1             2          225000.0    237024.0      12231.0   Unaccompanied
# 2             0          171000.0    247675.5      26005.5   Unaccompanied
# 3             0          225000.0    180000.0       9000.0   Unaccompanied
# 4             0          180000.0    337500.0      12852.0   Unaccompanied
#
#    ... DAYS_ID_PUBLISH OWN_CAR_AGE CNT_FAM_MEMBERS  HOUR_APPR_PROCESS_START  \
# 0  ...           -2256         NaN             2.0                       15
# 1  ...           -4133         NaN             4.0                        3
# 2  ...           -4340         NaN             2.0                       10
# 3  ...           -1621        12.0             2.0                       12
# 4  ...           -2870         NaN             1.0                       12
#
#         ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# 0            Kindergarten           NaN      0.665732           NaN
# 1  Business Entity Type 3      0.575699      0.535140      0.670652
# 2  Business Entity Type 3      0.092273      0.002272      0.154744
# 3           Trade: type 7      0.221815      0.120444           NaN
# 4                     XNA           NaN      0.722415      0.723837
#
#    DAYS_LAST_PHONE_CHANGE  AMT_REQ_CREDIT_BUREAU_YEAR
# 0                  -139.0                         1.0
# 1                  -957.0                         0.0
# 2                  -827.0                         1.0
# 3                  -569.0                         2.0
# 4                 -1544.0                         4.0
#
# [5 rows x 26 columns]

# %% [markdown]
# AMT_CREDIT에서 AMT_ANNUITY를 나누어 해당 사람이 몇개월에 걸쳐서 돈을 갚아야 하는지 변수화

# %%
train['AMT_CREDIT_TO_ANNUITY_RATIO']=train['AMT_CREDIT']/train['AMT_ANNUITY']
test['AMT_CREDIT_TO_ANNUITY_RATIO']=test['AMT_CREDIT']/test['AMT_ANNUITY']

# %%
loan.head()
# Out:
#    SK_ID_CURR  DAYS_CREDIT  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0      400486        -2413                   0        180000.0
# 1      400486         -941                   0         40500.0
# 2      400486        -1110                   0        114727.5
# 3      400486        -2133                   0        225000.0
# 4      400486         -391                   0        142290.0
#
#        CREDIT_TYPE
# 0  Consumer credit
# 1      Credit card
# 2  Consumer credit
# 3  Consumer credit
# 4  Consumer credit

# %% [markdown]
# 대출 평균 금액 변수화

# %%
loan.groupby(['SK_ID_CURR'])['AMT_CREDIT_SUM'].sum().reset_index()
# Out:
#        SK_ID_CURR  AMT_CREDIT_SUM
# 0          100026     5625000.000
# 1          100041      822305.160
# 2          100084       98100.000
# 3          100088     1777500.000
# 4          100100     3163743.450
# ...           ...             ...
# 25707      456153     2277901.575
# 25708      456212     1090489.500
# 25709      456238     1109502.000
# 25710      456253     3960000.000
# 25711      456255     3801919.500
#
# [25712 rows x 2 columns]

# %% [markdown]
# loan 파일에서 AMT_CREDIT_SUM(대출 금액), DAYS_CREDIT(일정), CNT_CREDIT_PROLONG(연장 횟수)의 평균을 column으로 추가한다.

# %%
train = pd.merge(train,loan.groupby(['SK_ID_CURR'])['AMT_CREDIT_SUM'].mean().reset_index(), on='SK_ID_CURR',how='left')
train.head()
# Out:
#    SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0      162716       0          0.0             0                1
# 1      361317       0          0.0             0                1
# 2      246925       0          1.0             0                0
# 3      294331       0          1.0             1                0
# 4      152173       0          0.0             0                1
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY NAME_TYPE_SUITE  \
# 0             0          101250.0    480060.0      22509.0   Unaccompanied
# 1             2          225000.0    237024.0      12231.0   Unaccompanied
# 2             0          171000.0    247675.5      26005.5   Unaccompanied
# 3             0          225000.0    180000.0       9000.0   Unaccompanied
# 4             0          180000.0    337500.0      12852.0   Unaccompanied
#
#    ... CNT_FAM_MEMBERS HOUR_APPR_PROCESS_START       ORGANIZATION_TYPE  \
# 0  ...             2.0                      15            Kindergarten
# 1  ...             4.0                       3  Business Entity Type 3
# 2  ...             2.0                      10  Business Entity Type 3
# 3  ...             2.0                      12           Trade: type 7
# 4  ...             1.0                      12                     XNA
#
#    EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  DAYS_LAST_PHONE_CHANGE  \
# 0           NaN      0.665732           NaN                  -139.0
# 1      0.575699      0.535140      0.670652                  -957.0
# 2      0.092273      0.002272      0.154744                  -827.0
# 3      0.221815      0.120444           NaN                  -569.0
# 4           NaN      0.722415      0.723837                 -1544.0
#
#    AMT_REQ_CREDIT_BUREAU_YEAR  AMT_CREDIT_TO_ANNUITY_RATIO  AMT_CREDIT_SUM
# 0                         1.0                    21.327469    3.150000e+05
# 1                         0.0                    19.378955    2.067966e+06
# 2                         1.0                     9.523966    6.219386e+04
# 3                         2.0                    20.000000    2.770443e+04
# 4                         4.0                    26.260504    1.068750e+05
#
# [5 rows x 28 columns]

# %%
test = pd.merge(test,loan.groupby(['SK_ID_CURR'])['AMT_CREDIT_SUM'].mean().reset_index(), on='SK_ID_CURR',how='left')
test.head()
# Out:
#    SK_ID_CURR  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      333864          1.0             1                0             1
# 1      253018          0.0             0                0             1
# 2      360625          1.0             0                0             0
# 3      287255          1.0             1                1             2
# 4      281149          0.0             0                1             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY NAME_TYPE_SUITE  \
# 0          225000.0    315000.0      16002.0   Unaccompanied
# 1           90000.0    225000.0      11250.0   Unaccompanied
# 2          202500.0    888840.0      37494.0   Unaccompanied
# 3          202500.0    168102.0      20079.0   Unaccompanied
# 4          306000.0    734166.0      49261.5   Unaccompanied
#
#        NAME_INCOME_TYPE  ... CNT_FAM_MEMBERS HOUR_APPR_PROCESS_START  \
# 0  Commercial associate  ...             2.0                      14
# 1               Working  ...             3.0                      12
# 2               Working  ...             1.0                      10
# 3               Working  ...             4.0                      14
# 4               Working  ...             2.0                      12
#
#         ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# 0           Self-employed           NaN      0.664203      0.179822
# 1  Business Entity Type 3      0.399164      0.259984           NaN
# 2           Self-employed      0.212372      0.470406      0.234015
# 3       Transport: type 4      0.823040      0.648610      0.304672
# 4  Business Entity Type 3           NaN      0.655703      0.315472
#
#    DAYS_LAST_PHONE_CHANGE  AMT_REQ_CREDIT_BUREAU_YEAR  \
# 0                 -1116.0                         0.0
# 1                  -982.0                         0.0
# 2                 -2052.0                         2.0
# 3                 -2420.0                         3.0
# 4                 -1511.0                         2.0
#
#    AMT_CREDIT_TO_ANNUITY_RATIO AMT_CREDIT_SUM
# 0                    19.685039   2.356490e+06
# 1                    20.000000   3.932777e+04
# 2                    23.706193   6.357150e+04
# 3                     8.372030   3.420000e+06
# 4                    14.903444   1.378325e+05
#
# [5 rows x 27 columns]

# %%
train = pd.merge(train,loan.groupby(['SK_ID_CURR'])['DAYS_CREDIT'].mean().reset_index(), on='SK_ID_CURR',how='left')
test = pd.merge(test,loan.groupby(['SK_ID_CURR'])['DAYS_CREDIT'].mean().reset_index(), on='SK_ID_CURR',how='left')

train = pd.merge(train,loan.groupby(['SK_ID_CURR'])['CNT_CREDIT_PROLONG'].mean().reset_index(), on='SK_ID_CURR',how='left')
test = pd.merge(test,loan.groupby(['SK_ID_CURR'])['CNT_CREDIT_PROLONG'].mean().reset_index(), on='SK_ID_CURR',how='left')

# %% [markdown]
# 사람 아이디 별로 대출받은 횟수도 추가한다.

# %%
#대출 받은 횟수
train = pd.merge(train,loan.groupby(['SK_ID_CURR']).size().reset_index().rename(columns={0:'COUNT'}))
test = pd.merge(test,loan.groupby(['SK_ID_CURR']).size().reset_index().rename(columns={0:'COUNT'}))

# %% [markdown]
# ## 불필요한 변수들 제거

# %%
train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS',
#        'HOUR_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'EXT_SOURCE_1',
#        'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_LAST_PHONE_CHANGE',
#        'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_CREDIT_TO_ANNUITY_RATIO',
#        'AMT_CREDIT_SUM', 'DAYS_CREDIT', 'CNT_CREDIT_PROLONG', 'COUNT'],
#       dtype='object')

# %%
train.dtypes
# Out:
# SK_ID_CURR                       int64
# TARGET                           int64
# CODE_GENDER                    float64
# FLAG_OWN_CAR                     int64
# FLAG_OWN_REALTY                  int64
# CNT_CHILDREN                     int64
# AMT_INCOME_TOTAL               float64
# AMT_CREDIT                     float64
# AMT_ANNUITY                    float64
# NAME_TYPE_SUITE                 object
# NAME_INCOME_TYPE                object
# NAME_EDUCATION_TYPE             object
# NAME_HOUSING_TYPE               object
# REGION_POPULATION_RELATIVE     float64
# DAYS_BIRTH                       int64
# DAYS_EMPLOYED                  float64
# DAYS_ID_PUBLISH                  int64
# OWN_CAR_AGE                    float64
# CNT_FAM_MEMBERS                float64
# HOUR_APPR_PROCESS_START          int64
# ORGANIZATION_TYPE               object
# EXT_SOURCE_1                   float64
# EXT_SOURCE_2                   float64
# EXT_SOURCE_3                   float64
# DAYS_LAST_PHONE_CHANGE         float64
# AMT_REQ_CREDIT_BUREAU_YEAR     float64
# AMT_CREDIT_TO_ANNUITY_RATIO    float64
# AMT_CREDIT_SUM                 float64
# DAYS_CREDIT                    float64
# CNT_CREDIT_PROLONG             float64
# COUNT                            int64
# dtype: object

# %% [markdown]
# object의 column들을과 알수 없는 변수 column들을 추후 모델 해석을 위해 제거합니다.

# %%
object_col = ['CODE_GENDER','FLAG_OWN_CAR', 'NAME_TYPE_SUITE','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_HOUSING_TYPE','ORGANIZATION_TYPE']
unknown_col = ['EXT_SOURCE_1','EXT_SOURCE_2','EXT_SOURCE_3']

# %%
train = train.drop(object_col,axis = 1)
train = train.drop(unknown_col,axis = 1)

test = test.drop(object_col,axis = 1)
test = test.drop(unknown_col,axis = 1)

# %% [markdown]
# ## 모델링

# %% [markdown]
# 모델링 하기 전에 서로 상관관계가 높은 input 변수를 제거한다. 왜냐하면 input 변수가 높은 상관성을 가질 때, shap value는 제대로 된 설명력을 발휘하지 못하기 때문이다.

# %%
train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS',
#        'HOUR_APPR_PROCESS_START', 'DAYS_LAST_PHONE_CHANGE',
#        'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_CREDIT_TO_ANNUITY_RATIO',
#        'AMT_CREDIT_SUM', 'DAYS_CREDIT', 'CNT_CREDIT_PROLONG', 'COUNT'],
#       dtype='object')

# %%
input_col = ['FLAG_OWN_REALTY', 'CNT_CHILDREN',
       'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
       'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
       'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'CNT_FAM_MEMBERS',
       'HOUR_APPR_PROCESS_START', 'DAYS_LAST_PHONE_CHANGE',
       'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_CREDIT_TO_ANNUITY_RATIO',
       'AMT_CREDIT_SUM', 'DAYS_CREDIT', 'CNT_CREDIT_PROLONG', 'COUNT']

# %%
corr = train[input_col].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col1 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col2 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col4 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col7 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col8 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col9 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col10 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col12 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col13 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col14 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col15 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col16 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col17 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row0_col18 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col3 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col4 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col5 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col6 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col7 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col8 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col9 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col10 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col11 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col12 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col13 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col14 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col15 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col16 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col17 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row1_col18 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col0 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col1 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col3 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col4 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col5 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col6 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col10 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col11 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col12 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col13 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col14 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col15 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col16 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col17 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row2_col18 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row3_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row3_col1 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_8bd65e46_1ebe_11ec_91da_982cbc7f47e7row3_col2 {
#             background-color:  #cbd8ee;

# %% [markdown]
# 높은 상관성을 가지는 변수는 다음과 같다.
#
# 1. CNT_CHILDREN, CNT_FAM_MEMBERS
# 2. AMT_CREDIT_TO_ANNUITY_RATIO, AMT_CREDIT
# 3. AMT_ANNUITY, AMT_CREDIT
#
# TARGET과 더 상관성이 높은 변수를 남기도록 한다.

# %%
train['CNT_CHILDREN'].corr(train['TARGET'])
# Out:
# 0.02020408753274091

# %%
train['CNT_FAM_MEMBERS'].corr(train['TARGET'])
# Out:
# 0.015364860802964925

# %%
del train['CNT_FAM_MEMBERS']
del test['CNT_FAM_MEMBERS']

# %%
print(train['AMT_CREDIT_TO_ANNUITY_RATIO'].corr(train['TARGET']))
print(train['AMT_CREDIT'].corr(train['TARGET']))
# Out:
# -0.0170488245810787
# -0.01724199702034605

# %%
del train['AMT_CREDIT']
del test['AMT_CREDIT']

# %%
train.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'AMT_ANNUITY', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE',
#        'HOUR_APPR_PROCESS_START', 'DAYS_LAST_PHONE_CHANGE',
#        'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_CREDIT_TO_ANNUITY_RATIO',
#        'AMT_CREDIT_SUM', 'DAYS_CREDIT', 'CNT_CREDIT_PROLONG', 'COUNT'],
#       dtype='object')

# %%
input_col= ['FLAG_OWN_REALTY', 'CNT_CHILDREN',
       'AMT_INCOME_TOTAL', 'AMT_ANNUITY', 'REGION_POPULATION_RELATIVE',
       'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE',
       'HOUR_APPR_PROCESS_START', 'DAYS_LAST_PHONE_CHANGE',
       'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_CREDIT_TO_ANNUITY_RATIO',
       'AMT_CREDIT_SUM', 'DAYS_CREDIT', 'CNT_CREDIT_PROLONG', 'COUNT']

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier(n_estimators = 100, learning_rate = 0.1)
model.fit(train[input_col],train['TARGET'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:47:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=True,
#               validate_parameters=1, verbosity=None)

# %%
model.predict(test[input_col])
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
